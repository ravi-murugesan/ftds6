# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/train.csv')

# %%
df.iloc[271]
# Out:
# PassengerId                             272
# Survived                                  1
# Pclass                                    3
# Name           Tornquist, Mr. William Henry
# Sex                                    male
# Age                                      25
# SibSp                                     0
# Parch                                     0
# Ticket                                 LINE
# Fare                                      0
# Cabin                                   NaN
# Embarked                                  S
# Name: 271, dtype: object

# %%
df1['Ticket'].nunique()
# Out:
# 681

# %%
df1.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df1.Age.isna().sum(),df1.Embarked.isna().sum(),df1.Cabin.isna().sum()
# Out:
# (177, 2, 687)

# %%
dft = pd.read_csv('./data/test.csv')
dft
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
dft['Ticket'].nunique()
# Out:
# 363

# %%
dft.isnull().any()
# Out:
# PassengerId    False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked       False
# dtype: bool

# %%
dft.Age.isna().sum(),dft.Fare.isna().sum(),dft.Cabin.isna().sum()
# Out:
# (86, 1, 327)

# %%
df1.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# df1['Ticket_1'] = df1['Ticket'].apply(lambda x: x.split(' ')[-1])

# %%
df1.Ticket_1.nunique()
# Out:
# 679

# %%
df1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Ticket_1
# 0      0         A/5 21171   7.2500   NaN        S    21171
# 1      0          PC 17599  71.2833   C85        C    17599
# 2      0  STON/O2. 3101282   7.9250   NaN        S  3101282

# %%
df1.Age.isna().sum(),df1.Embarked.isna().sum(),df1.Cabin.isna().sum()
# Out:
# (177, 2, 687)

# %%
print(df1[df1['Embarked'].isnull()])
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Ticket_1
# 61   female  38.0      0      0  113572  80.0   B28      NaN   113572
# 829  female  62.0      0      0  113572  80.0   B28      NaN   113572

# %%
# df1['Surname'] = df1['Name'].apply(lambda x: x.split(',')[0])
df1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Ticket_1    Surname
# 0      0         A/5 21171   7.2500   NaN        S    21171     Braund
# 1      0          PC 17599  71.2833   C85        C    17599    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  3101282  Heikkinen

# %%
print(df1[df1['Cabin'] == 'B28'])
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Ticket_1 Surname
# 61   female  38.0      0      0  113572  80.0   B28      NaN   113572   Icard
# 829  female  62.0      0      0  113572  80.0   B28      NaN   113572   Stone

# %%
df1['Cabin'].nunique(),df1['Embarked'].nunique(),df1['Surname'].nunique()
# Out:
# (147, 3, 667)

# %%
df2 = df1.drop(['Ticket','Name','Surname','Cabin','Age'],axis=1)
df2.head(3)
# Out:
#    PassengerId  Survived  Pclass     Sex  SibSp  Parch     Fare Embarked  \
# 0            1         0       3    male      1      0   7.2500        S
# 1            2         1       1  female      1      0  71.2833        C
# 2            3         1       3  female      0      0   7.9250        S
#
#   Ticket_1
# 0    21171
# 1    17599
# 2  3101282

# %%
df2['Sex'] = df2['Sex'].apply(lambda x: 1 if x =='male' else 0)
df2.head(3)
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare Embarked Ticket_1
# 0            1         0       3    1      1      0   7.2500        S    21171
# 1            2         1       1    0      1      0  71.2833        C    17599
# 2            3         1       3    0      0      0   7.9250        S  3101282

# %%
df2.groupby('Embarked').count()
# Out:
#           PassengerId  Survived  Pclass  Sex  SibSp  Parch  Fare  Ticket_1
# Embarked
# C                 168       168     168  168    168    168   168       168
# Q                  77        77      77   77     77     77    77        77
# S                 644       644     644  644    644    644   644       644

# %%
df2 = pd.concat([df2,pd.get_dummies(df2['Embarked'], prefix='Embarked')],axis=1)
df2
# Out:
#      PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare Embarked  \
# 0              1         0       3    1      1      0   7.2500        S
# 1              2         1       1    0      1      0  71.2833        C
# 2              3         1       3    0      0      0   7.9250        S
# 3              4         1       1    0      1      0  53.1000        S
# 4              5         0       3    1      0      0   8.0500        S
# ..           ...       ...     ...  ...    ...    ...      ...      ...
# 886          887         0       2    1      0      0  13.0000        S
# 887          888         1       1    0      0      0  30.0000        S
# 888          889         0       3    0      1      2  23.4500        S
# 889          890         1       1    1      0      0  30.0000        C
# 890          891         0       3    1      0      0   7.7500        Q
#
#     Ticket_1  Embarked_C  Embarked_Q  Embarked_S
# 0      21171           0           0           1
# 1      17599           1           0           0
# 2    3101282           0           0           1
# 3     113803           0           0           1
# 4     373450           0           0           1
# ..       ...         ...         ...         ...
# 886   211536           0           0           1
# 887   112053           0           0           1
# 888     6607           0           0           1
# 889   111369           1           0           0
# 890   370376           0           1           0
#
# [891 rows x 12 columns]

# %%
# now drop the original column (you don't need it anymore)
df2.drop(['Embarked'],axis=1, inplace=True)
df2
# Out:
#      PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare Ticket_1  \
# 0              1         0       3    1      1      0   7.2500    21171
# 1              2         1       1    0      1      0  71.2833    17599
# 2              3         1       3    0      0      0   7.9250  3101282
# 3              4         1       1    0      1      0  53.1000   113803
# 4              5         0       3    1      0      0   8.0500   373450
# ..           ...       ...     ...  ...    ...    ...      ...      ...
# 886          887         0       2    1      0      0  13.0000   211536
# 887          888         1       1    0      0      0  30.0000   112053
# 888          889         0       3    0      1      2  23.4500     6607
# 889          890         1       1    1      0      0  30.0000   111369
# 890          891         0       3    1      0      0   7.7500   370376
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 11 columns]

# %%
df2.loc[[179],7:8] = 0

# %%
df2['Ticket_1'] = df2['Ticket_1'].apply(lambda x: 0 if x == 'LINE' else x)
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex              int64
# SibSp            int64
# Parch            int64
# Fare           float64
# Ticket_1        object
# Embarked_C       uint8
# Embarked_Q       uint8
# Embarked_S       uint8
# dtype: object

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex              int64
# SibSp            int64
# Parch            int64
# Fare           float64
# Ticket_1         int64
# Embarked_C       uint8
# Embarked_Q       uint8
# Embarked_S       uint8
# dtype: object

# %%
df2['Ticket_1'] = pd.to_numeric(df2['Ticket_1'])
df2
# Out:
#      PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare  Ticket_1  \
# 0              1         0       3    1      1      0   7.2500     21171
# 1              2         1       1    0      1      0  71.2833     17599
# 2              3         1       3    0      0      0   7.9250   3101282
# 3              4         1       1    0      1      0  53.1000    113803
# 4              5         0       3    1      0      0   8.0500    373450
# ..           ...       ...     ...  ...    ...    ...      ...       ...
# 886          887         0       2    1      0      0  13.0000    211536
# 887          888         1       1    0      0      0  30.0000    112053
# 888          889         0       3    0      1      2  23.4500      6607
# 889          890         1       1    1      0      0  30.0000    111369
# 890          891         0       3    1      0      0   7.7500    370376
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 11 columns]

# %%
df = df2.drop('PassengerId',axis=1)
df.head(3)
# Out:
#    Survived  Pclass  Sex  SibSp  Parch     Fare  Ticket_1  Embarked_C  \
# 0         0       3    1      1      0   7.2500     21171           0
# 1         1       1    0      1      0  71.2833     17599           1
# 2         1       3    0      0      0   7.9250   3101282           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1

# %% [markdown]
# #  Trainin

# %%
# Separate out the target

X = df.drop('Survived',axis=1)
y = df['Survived']
X.head(3)
# Out:
#    Pclass  Sex  SibSp  Parch     Fare  Ticket_1  Embarked_C  Embarked_Q  \
# 0       3    1      1      0   7.2500     21171           0           0
# 1       1    0      1      0  71.2833     17599           1           0
# 2       3    0      0      0   7.9250   3101282           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1

# %%
y.shape, X.shape
# Out:
# ((891,), (891, 9))

# %%
# Import module to split dataset
from sklearn.model_selection import train_test_split
# Split data set into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_clf2 = GradientBoostingClassifier(n_estimators=30, learning_rate=0.25,
                                     max_depth=20, random_state=42, max_leaf_nodes=50)
gb_clf2.fit(X_train, y_train)
predictions = gb_clf2.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))

print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix:
# [[139  33]
#  [ 25  71]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       172
#            1       0.68      0.74      0.71        96
#
#     accuracy                           0.78       268
#    macro avg       0.77      0.77      0.77       268
# weighted avg       0.79      0.78      0.79       268

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))

print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix:
# [[216   7]
#  [ 78  56]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.97      0.84       223
#            1       0.89      0.42      0.57       134
#
#     accuracy                           0.76       357
#    macro avg       0.81      0.69      0.70       357
# weighted avg       0.79      0.76      0.74       357
